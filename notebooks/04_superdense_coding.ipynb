# %% [markdown]
# # 04 — Superdense coding
#
# Два классических бита через один кубит при заранее разделённой Bell-паре.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT / "src"))

from circuits import create_superdense_coding_circuit, run_circuit

for msg in ['00', '01', '10', '11']:
    counts = run_circuit(create_superdense_coding_circuit(msg), shots=512)
    print(msg, counts)

# %% [markdown]
# Superdense coding показывает, что entanglement — ресурс для communication tasks (связь с quantum information).
