# %% [markdown]
# # 00 — Проверка окружения
#
# Технический старт: убедимся, что Qiskit, Aer и примитивы работают.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT / "src"))

import platform
import qiskit
import qiskit_aer
import numpy as np
import matplotlib

print('Python:', platform.python_version())
print('Qiskit:', qiskit.__version__)
print('Aer:', qiskit_aer.__version__)

# %%
from qiskit import QuantumCircuit
from qiskit.primitives import StatevectorSampler
from qiskit_aer import AerSimulator

qc = QuantumCircuit(1, 1)
qc.h(0)
qc.measure(0, 0)

sim = AerSimulator()
counts = sim.run(qc, shots=1000).result().get_counts()
print('Aer counts:', counts)

sampler = StatevectorSampler()
job = sampler.run([qc], shots=1000)
print('Sampler quasi-dist:', job.result()[0].data.meas.get_counts())

# %% [markdown]
# ## Как запустить остальные ноутбуки
#
# ```bash
# python -m venv .venv
# pip install -r requirements.txt
# pip install -e .
# jupyter notebook
# ```
#
# Откройте файлы в `notebooks/` по порядку номеров.
