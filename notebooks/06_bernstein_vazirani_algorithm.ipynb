# %% [markdown]
# # 06 — Bernstein–Vazirani

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT / "src"))

from circuits import create_bernstein_vazirani_circuit, run_circuit

secret = '1011'
counts = run_circuit(create_bernstein_vazirani_circuit(secret), shots=1024)
recovered = max(counts, key=counts.get)
print('Secret:', secret)
print('Recovered:', recovered)
print('Counts:', counts)

# %% [markdown]
# Один запрос к oracle вместо n классических — наглядный пример для портфолио.
