# %% [markdown]
# # 05 — Deutsch–Jozsa

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT / "src"))

from circuits import create_deutsch_jozsa_circuit, run_circuit

for kind in ['constant', 'balanced']:
    c = run_circuit(create_deutsch_jozsa_circuit(2, kind), shots=1024)
    print(kind, c)

# %% [markdown]
# Deutsch–Jozsa — учебный пример квантового параллелизма и интерференции. Практическая ценность ограничена, но алгоритм показывает извлечение глобального свойства функции.
