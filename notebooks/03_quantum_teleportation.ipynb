# %% [markdown]
# # 03 — Квантовая телепортация

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT / "src"))

from circuits import teleportation_fidelity, create_teleportation_circuit_diagram
from visualization import save_circuit_image

save_circuit_image(create_teleportation_circuit_diagram(), str(ROOT / 'images' / 'teleportation_circuit.png'))
print('Fidelity (statevector):', teleportation_fidelity())

# %% [markdown]
# **Вывод:** Квантовая телепортация не означает физическую передачу частицы. Передаётся состояние, причём для восстановления требуется классическая информация, поэтому faster-than-light communication не возникает.
